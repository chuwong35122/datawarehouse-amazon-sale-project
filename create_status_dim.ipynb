# %% [markdown]
# # Create Status Dim

# %%
import pandas as pd
import numpy as np

# %%
sale_df = pd.read_csv('data/datetime_amazon_sale_report.csv')
sale_df.head()
# Out:
#               order_id        date                        status fulfilment  \
# 0  405-8078784-5731545  30-04-2022                     Cancelled   Merchant
# 1  171-9198151-1101146  30-04-2022  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  30-04-2022                       Shipped     Amazon
# 3  403-9615377-8133951  30-04-2022                     Cancelled   Merchant
# 4  407-1069790-7240320  30-04-2022                       Shipped     Amazon
#
#   sales_channel ship_service_level    style              sku       category  \
# 0     Amazon.in           Standard   SET389   SET389-KR-NP-S            Set
# 1     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3     Amazon.in           Standard    J0341       J0341-DR-L  Western Dress
# 4     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
sale_df[sale_df.columns[0:10]]
# Out:
#                    order_id        date                        status  \
# 0       405-8078784-5731545  30-04-2022                     Cancelled
# 1       171-9198151-1101146  30-04-2022  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  30-04-2022                       Shipped
# 3       403-9615377-8133951  30-04-2022                     Cancelled
# 4       407-1069790-7240320  30-04-2022                       Shipped
# ...                     ...         ...                           ...
# 121264  406-6001380-7673107  31-05-2022                       Shipped
# 121265  402-9551604-7544318  31-05-2022                       Shipped
# 121266  407-9547469-3152358  31-05-2022                       Shipped
# 121267  402-6184140-0545956  31-05-2022                       Shipped
# 121268  408-7436540-8728312  31-05-2022                       Shipped
#
#        fulfilment sales_channel ship_service_level    style              sku  \
# ...

# %%
sale_df[sale_df.columns[11:20]]
# Out:
#        courier_status  qty currency    amount         ship_city  \
# 0                 NaN    0      USD   7.77144   West Deniseland
# 1             Shipped    1      USD   4.87200  New Cesarborough
# 2             Shipped    1      USD   3.94800       Matthewtown
# 3                 NaN    0      USD   9.03996        Bentonstad
# 4             Shipped    1      USD   6.88800     West Kimberly
# ...               ...  ...      ...       ...               ...
# 121264        Shipped    1      USD   6.20400  Port Jefferytown
# 121265        Shipped    1      USD  11.98800         Port Dawn
# 121266        Shipped    1      USD   8.28000   North Markburgh
# 121267        Shipped    1      USD  14.38800         New Holly
# 121268        Shipped    1      USD   8.35200        New Shelby
#
#             ship_state  ship_postal_code ship_country  \
# 0            Minnesota             26450          USA
# 1             Nebraska             96610          USA
# ...

# %%
sale_df.dropna(inplace=True)

# %%
status_df = pd.DataFrame(columns=['statusName'])
status_df['statusName'] = sale_df['status'].unique()
status_df
# Out:
#                        statusName
# 0    Shipped - Delivered to Buyer
# 1                         Shipped
# 2    Shipped - Returned to Seller
# 3     Shipped - Rejected by Buyer
# 4                       Cancelled
# 5       Shipped - Lost in Transit
# 6      Shipped - Out for Delivery
# 7   Shipped - Returning to Seller
# 8             Shipped - Picked Up
# 9                         Pending
# 10  Pending - Waiting for Pick Up
# 11              Shipped - Damaged

# %%
status_df.to_csv('dimensions/status_dim_file.csv', index=False)
