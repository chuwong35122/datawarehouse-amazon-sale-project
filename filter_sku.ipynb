# %% [markdown]
# # Get SKU that exist in Amazon Sale Report
# Get sku thaht intersect between amazon sale report and sale report (inner join)

# %%
import pandas as pd
import numpy as np

# %%
df_amazon_sale_report_new = pd.read_csv('./data/generated_amazon_sale_report.csv')

# %%
df_sale_report_new = pd.read_csv('./data/cleaned_sale_report.csv')

# %%
df_sale_report_new.shape[0]
# Out:
# 9173

# %%
df_amazon_sale_report_new.shape[0]
# Out:
# 121269

# %%
print(df_sale_report_new['sku'].str.contains('#REF').any())
df_sale_report_new = df_sale_report_new[~df_sale_report_new['sku'].str.contains('#REF')]
df_sale_report_new.shape[0]
# Out:
# False
# 9173

# %%
sku_list_amazon = df_amazon_sale_report_new['sku'].unique().tolist()
sku_list_sale = df_sale_report_new['sku'].unique().tolist()

# %%
#print both list
print(len(sku_list_amazon))
print(len(sku_list_sale))
print(sku_list_amazon)
print(sku_list_sale)
# Out:
# 6617
# 9173
# ...

# %%
#count how many sku name are in both list get a list of the intersected sku
sku_intersect = list(set(sku_list_amazon) & set(sku_list_sale))
print(len(sku_intersect))
# Out:
# 6617

# %%
for i in range(len(sku_list_amazon)):
    if sku_list_amazon[i] not in sku_list_sale:
        print(sku_list_amazon[i])

# %%
len(sku_intersect)
# Out:
# 6617

# %%
print(sku_intersect)
# Out:
# ['JNE3576-KR-XXL', 'SAR159', 'SET241-KR-PP-XS', 'JNE3389-KR-XL', 'J0351-SET-XL', 'JNE3425-KR-S', 'SET184-KR-PP-XS', 'JNE3427-KR-L', 'SET053-KR-NP-XL', 'SET435-KR-NP-L', 'JNE3806-KR-XL', 'JNE3714-KR-XS', 'MEN5030-KR-XXXL', 'PJNE3068-KR-5XL', 'J0154-DR-M', 'JNE1975-KR-309-XXL', 'J0399-DR-XXL', 'SET187-KR-DH-L', 'SET449-KR-NP-S', 'JNE3861-DR-M', 'JNE3413-KR-S', 'JNE3701-KR-M', 'JNE3791-DR-XL', 'SET252-KR-PP-XL', 'JNE3694-KR-S', 'J0119-TP-XL', 'J0235-SKD-M', 'JNE3471-KR-XS', 'SET383-KR-NP-XL', 'J0174-TP-XS', 'J0175-KR-L', 'CH203-MAROON-L', 'JNE3792-KR-M', 'JNE3485-KR-XL', 'SET278-KR-NP-XS', 'MEN5014-KR-XL', 'JNE3706-DR-M', 'JNE3773-KR-L', 'SET203-KR-DPT-XXL', 'J0351-SET-L', 'JNE3501-KR-M', 'SET094-KR-NP-L', 'SET308-KR-PP-XXXL', 'SET258-KR-PP-XS', 'J0123-TP-XS', 'J0033-KR-XL', 'MEN5002-KR-S', 'MEN5008-KR-S', 'SET353-KR-NP-L', 'J0122-TP-XXL', 'JNE3252-KR-XXL', 'JNE3420-KR-M', 'JNE3468-KR-XS', 'JNE2100-KR-144-XL', 'J0346-SET-XXXL', 'SET288-KR-NP-L', 'AN205-YELLOW-XL', 'SET373-KR-PP-M', 'JNE
# ...

# %%
df_amazon_sale_filtered_sku = pd.DataFrame()
df_amazon_sale_filtered_sku = df_amazon_sale_report_new[df_amazon_sale_report_new['sku'].isin(sku_intersect)]
df_sale_filtered_sku = pd.DataFrame()
df_sale_filtered_sku = df_sale_report_new[df_sale_report_new['sku'].isin(sku_intersect)]

# %%
sku_old = df_sale_report_new['sku']
sku_new = df_sale_filtered_sku['sku']

print(len(sku_old))
print(len(sku_new))
# Out:
# 9173
# 6617

# %%
df_amazon_sale_filtered_sku.shape[0]
# Out:
# 121269

# %%
df_amazon_sale_filtered_sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121269 entries, 0 to 121268
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   order_id            121269 non-null  object
#  1   date                121269 non-null  object
#  2   status              121269 non-null  object
#  3   fulfilment          121269 non-null  object
#  4   ship_service_level  121269 non-null  object
#  5   style               121269 non-null  object
#  6   sku                 121269 non-null  object
#  7   category            121269 non-null  object
#  8   size                121269 non-null  object
#  9   asin                121269 non-null  object
#  10  courier_status      114855 non-null  object
#  11  qty                 121269 non-null  int64
#  12  currency            121269 non-null  object
#  13  amount              113930 non-null  float64
#  14  ship_city           121269 non-null  object
# ...

# %%
df_sale_report_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9173 entries, 0 to 9172
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sku        9173 non-null   object
#  1   design_no  9173 non-null   object
#  2   stock      9173 non-null   float64
#  3   category   9173 non-null   object
#  4   size       9173 non-null   object
#  5   color      9173 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 501.6+ KB

# %%
df_sale_filtered_sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6617 entries, 1 to 9168
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sku        6617 non-null   object
#  1   design_no  6617 non-null   object
#  2   stock      6617 non-null   float64
#  3   category   6617 non-null   object
#  4   size       6617 non-null   object
#  5   color      6617 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 361.9+ KB

# %%
sku_list_sale = df_amazon_sale_report_new['sku'].tolist()
sku_dict = {}
for sku in sku_list_sale:
    if sku in sku_dict:
        sku_dict[sku] += 1
    else:
        sku_dict[sku] = 1

print(sku_dict)

sku_dict = {k: v for k, v in sorted(sku_dict.items(), key=lambda item: item[1], reverse=True)}
print(sku_dict)
print(len(sku_list_sale))
# Out:
# {'SET389-KR-NP-S': 36, 'JNE3781-KR-XXXL': 109, 'JNE3371-KR-XL': 14, 'J0341-DR-L': 292, 'JNE3671-TU-XXXL': 17, 'SET264-KR-NP-XL': 139, 'J0095-SET-L': 76, 'JNE3405-KR-S': 443, 'JNE3461-KR-XXL': 35, 'JNE3500-KR-XS': 13, 'JNE3405-KR-XS': 234, 'SET182-KR-DH-XS': 30, 'J0351-SET-L': 35, 'PJNE3368-KR-6XL': 25, 'JNE3721-KR-XXL': 109, 'JNE3405-KR-XL': 209, 'JNE3697-KR-XXL': 67, 'SET254-KR-NP-XS': 16, 'JNE3795-KR-XXXL': 33, 'SET345-KR-NP-M': 272, 'JNE3373-KR-L': 125, 'SET291-KR-PP-M': 210, 'MEN5002-KR-L': 65, 'NW030-TP-PJ-XS': 23, 'JNE3415-KR-XXXL': 5, 'JNE3567-KR-M': 317, 'JNE2132-KR-398-XXXL': 5, 'J0341-DR-S': 278, 'MEN5009-KR-XL': 64, 'J0011-LCD-M': 37, 'JNE3766-KR-M': 14, 'JNE3373-KR-XL': 187, 'MEN5001-KR-XL': 13, 'SET345-KR-NP-L': 216, 'JNE3787-KR-S': 53, 'JNE3543-KR-S': 48, 'JNE3405-KR-L': 535, 'J0211-DR-XXL': 5, 'J0401-DR-XXXL': 18, 'SET360-KR-NP-M': 16, 'SET268-KR-NP-L': 362, 'SET183-KR-DH-S': 79, 'J0230-SKD-L': 297, 'JNE3744-TU-S': 10, 'JNE3510-KR-S': 141, 'JNE3405-KR-M': 394, 'J0186-S
# ...
