# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/datetime_amazon_sale_report.csv')

# %%
#map shipping level to from expedite to prime and standard to non-prime
df['ship_service_level'] = df['ship_service_level'].map({'Expedited': 'prime', 'Standard': 'regular'})

# %%
df.head()
# Out:
#               order_id        date                        status fulfilment  \
# 0  405-8078784-5731545  30-04-2022                     Cancelled   Merchant
# 1  171-9198151-1101146  30-04-2022  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  30-04-2022                       Shipped     Amazon
# 3  403-9615377-8133951  30-04-2022                     Cancelled   Merchant
# 4  407-1069790-7240320  30-04-2022                       Shipped     Amazon
#
#   sales_channel ship_service_level    style              sku       category  \
# 0     Amazon.in            regular   SET389   SET389-KR-NP-S            Set
# 1     Amazon.in            regular  JNE3781  JNE3781-KR-XXXL          kurta
# 2     Amazon.in              prime  JNE3371    JNE3371-KR-XL          kurta
# 3     Amazon.in            regular    J0341       J0341-DR-L  Western Dress
# 4     Amazon.in              prime  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
#save to csv
df.to_csv('data/amazon_sale_report_final_version.csv', index=False)
